# %% [markdown]
# # Exam Ready Priority A (Plug-and-Play)
#
# Use this notebook during the exam.
#
# - You only edit values in **PASTE INPUTS HERE** blocks.
# - You run the cell and read `result["answer"]`.
# - You do **not** edit `exam_templates/priority_a_templates.py` during the exam.

# %%
import numpy as np
from pathlib import Path

from exam_templates.priority_a_templates import (
    project_3d_point_template,
    estimate_homography_dlt_template,
    map_undistorted_to_distorted_pixel_template,
    harris_from_tensor_with_nms_template,
    rootsift_ratio_match_count_template,
    zhang_focal_from_checkerboards_template,
    epipolar_distance_template,
    triangulate_point_nonlinear_template,
    camera_center_from_rt_template,
    transform_point_between_camera_frames_template,
    ransac_iterations_template,
    ransac_threshold_from_sigma_template,
    structured_light_phase_unwrap_pixel_template,
    line_ransac_inlier_count_template,
    example_2024_q1_project_3d_point,
    example_2024_q2_estimate_homography,
    example_2024_q4_distortion,
    example_2024_q6_harris,
    example_2024_q9_rootsift_ratio,
    example_2024_q10_zhang_focal,
    example_2024_q15_epipolar_distance,
    example_2024_q16_triangulate_nonlin,
    example_2024_q17_camera_center,
    example_2024_q18_transform_point,
    example_2024_q19_ransac_iterations,
    example_2024_q20_ransac_threshold_dof1,
    example_2024_q20_ransac_threshold_dof2,
    example_2024_q21_structured_light,
    example_2023_q13_line_inlier_count,
    example_2023_q14_ransac_iterations,
)
from exam_toolkit.core import rodrigues_to_matrix
from exam_toolkit.projection import projection_matrix
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 import numpy as np
#       2 from pathlib import Path
#       3
# ----> 4 from exam_templates.priority_a_templates import (
#       5     project_3d_point_template,
#       6     estimate_homography_dlt_template,
#       7     map_undistorted_to_distorted_pixel_template,
#
# ModuleNotFoundError: No module named 'exam_templates'

# %% [markdown]
# ## TEMPLATE: project_3d_point_template
#
# **When to use:** Project a 3D world point into image pixels with K, R, t.
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE
Q_world = np.array([[-0.38], [0.10], [1.32]], dtype=float)
t = np.array([[-0.08], [0.01], [0.03]], dtype=float)
rvec = np.array([0.2, 0.2, -0.1], dtype=float)
f = 1400.0
principal_point = (750.0, 520.0)

# RUN
result = project_3d_point_template(
    Q_world=Q_world,
    t=t,
    rvec=rvec,
    f=f,
    principal_point=principal_point,
    verbose=True,
)

print('ANSWER:', result['answer'].reshape(-1))
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## TEMPLATE: estimate_homography_dlt_template
#
# **When to use:** Estimate homography from point correspondences (p_target ~ H p_source).
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE
p_target = np.array([
    [145.349587, -0.11291513, 1.91640565, -0.60812996],
    [105.603820,  0.05627926, 1.79040110, -0.23218218],
], dtype=float)

p_source = np.array([
    [1.3753556, -1.77072961, 2.94511795, 0.04032374],
    [0.30936653, 0.37172814, 1.44007577, -0.03173825],
], dtype=float)

# RUN
result = estimate_homography_dlt_template(
    p_target=p_target,
    p_source=p_source,
    normalize=False,
    check_point_source=p_source[:, :1],
    verbose=True,
)

print('ANSWER (H):')
print(result['answer'])
print('SCALED H for option matching:')
print(result['intermediates']['H_scaled_for_option_matching'])
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## TEMPLATE: map_undistorted_to_distorted_pixel_template
#
# **When to use:** Forward-map an undistorted pixel through radial distortion to distorted image pixel.
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE
undistorted_pixel = np.array([[400.0], [500.0]], dtype=float)
K = np.array([[300.0, 0.0, 840.0], [0.0, 300.0, 620.0], [0.0, 0.0, 1.0]], dtype=float)
dist_coeffs = [-0.2, 0.01, -0.03]  # k3, k5, k7

# RUN
result = map_undistorted_to_distorted_pixel_template(
    undistorted_pixel=undistorted_pixel,
    K=K,
    dist_coeffs=dist_coeffs,
    verbose=True,
)

print('ANSWER:', result['answer'].reshape(-1))
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## TEMPLATE: harris_from_tensor_with_nms_template
#
# **When to use:** Compute Harris response from structure tensor and extract corners with NMS.
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE (Option A: use npy file)
npy_path = np.load("harris.npy", allow_pickle=True).item()
print(npy_path.keys())
k = 0.06
tau = 5.0
neighborhood = 8

# Option B: pass arrays directly
# gxx = ...
# gyy = ...
# gxy = ...

# RUN
result = harris_from_tensor_with_nms_template(
    npy_path=npy_path,
    # gxx=gxx, gyy=gyy, gxy=gxy,
    k=k,
    tau=tau,
    neighborhood=neighborhood,
    verbose=True,
)

print('ANSWER (corner coordinates):', result['answer'])
print('CORNER COUNT:', result['intermediates']['corner_count'])
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # PASTE INPUTS HERE (Option A: use npy file)
# ----> 2 npy_path = np.load("harris.npy", allow_pickle=True).item()
#       3 print(npy_path.keys())
#       4 k = 0.06
#       5 tau = 5.0
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## TEMPLATE: rootsift_ratio_match_count_template
#
# **When to use:** Count descriptor matches passing 2-NN ratio test with RootSIFT.
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE (Option A: use npy file)
npy_path = Path('notebooks/materials_2024/sift_data.npy')
ratio = 0.8

# Option B: pass descriptors directly
# des1 = ...
# des2 = ...

# RUN
result = rootsift_ratio_match_count_template(
    npy_path=npy_path,
    # des1=des1, des2=des2,
    ratio=ratio,
    include_plain_sift_comparison=True,
    verbose=True,
)

print('ANSWER (RootSIFT match count):', result['answer'])
print('PLAIN SIFT COUNT:', result['intermediates']['plain_sift_count'])
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## TEMPLATE: zhang_focal_from_checkerboards_template
#
# **When to use:** Estimate focal lengths from multiple checkerboard views (Zhang workflow).
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE (Option A: from image folder)
folder = Path('notebooks/materials_2024')
board_glob = 'board*.jpg'
pattern_size = (7, 10)
square_size_m = 15.0 / 1000.0

# Option B: pass qs and Q_world directly
# qs = [...]
# Q_world = ...

# RUN
result = zhang_focal_from_checkerboards_template(
    folder=folder,
    board_glob=board_glob,
    pattern_size=pattern_size,
    square_size_m=square_size_m,
    reorder_world_points=True,
    verbose=True,
)

print('ANSWER (fx):', result['answer'])
print('fy:', result['intermediates']['fy'])
print('K_est:')
print(result['intermediates']['K_est'])
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## TEMPLATE: epipolar_distance_template
#
# **When to use:** Compute point-to-epipolar-line distance between two calibrated camera views.
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE
K = np.array([[300.0, 0.0, 840.0], [0.0, 300.0, 620.0], [0.0, 0.0, 1.0]], dtype=float)
R1 = rodrigues_to_matrix(np.array([-2.3, -0.7, 1.0], dtype=float))
t1 = np.array([[0.0], [-1.0], [4.0]], dtype=float)
R2 = rodrigues_to_matrix(np.array([-0.6, 0.5, -0.9], dtype=float))
t2 = np.array([[0.0], [0.0], [9.0]], dtype=float)
p1 = np.array([[853.0], [656.0]], dtype=float)
p2 = np.array([[814.0], [655.0]], dtype=float)

# RUN
result = epipolar_distance_template(
    K1=K,
    R1=R1,
    t1=t1,
    K2=K,
    R2=R2,
    t2=t2,
    p1=p1,
    p2=p2,
    distance_in_image=1,
    verbose=True,
)

print('ANSWER (distance):', result['answer'])
print('EPIPOLAR LINE:', result['intermediates']['epipolar_line'].reshape(-1))
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## TEMPLATE: triangulate_point_nonlinear_template
#
# **When to use:** Triangulate 3D point from multi-view image points and camera projections.
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE
K = np.array([[300.0, 0.0, 840.0], [0.0, 300.0, 620.0], [0.0, 0.0, 1.0]], dtype=float)
R1 = rodrigues_to_matrix(np.array([-2.3, -0.7, 1.0], dtype=float)); t1 = np.array([[0.0], [-1.0], [4.0]], dtype=float)
R2 = rodrigues_to_matrix(np.array([-0.6, 0.5, -0.9], dtype=float)); t2 = np.array([[0.0], [0.0], [9.0]], dtype=float)
R3 = rodrigues_to_matrix(np.array([-0.1, 0.9, -1.2], dtype=float)); t3 = np.array([[-1.0], [-6.0], [28.0]], dtype=float)

q_list = [
    np.array([[853.0], [656.0]], dtype=float),
    np.array([[814.0], [655.0]], dtype=float),
    np.array([[798.0], [535.0]], dtype=float),
]
P_list = [
    projection_matrix(K, R1, t1),
    projection_matrix(K, R2, t2),
    projection_matrix(K, R3, t3),
]

# RUN
result = triangulate_point_nonlinear_template(
    q_list=q_list,
    P_list=P_list,
    verbose=True,
)

print('ANSWER (Q nonlinear):', result['answer'].reshape(-1))
print('LINEAR INIT:', result['intermediates']['Q_linear_init'].reshape(-1))
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## TEMPLATE: camera_center_from_rt_template
#
# **When to use:** Compute camera center C in world coordinates from R and t.
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE
R = rodrigues_to_matrix(np.array([-1.9, 0.1, -0.2], dtype=float))
t = np.array([[-1.7], [1.3], [1.5]], dtype=float)

# RUN
result = camera_center_from_rt_template(R=R, t=t, verbose=True)

print('ANSWER (camera center C):', result['answer'].reshape(-1))
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## TEMPLATE: transform_point_between_camera_frames_template
#
# **When to use:** Transform a 3D point from one camera frame into another camera frame.
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE
point_in_src_cam = np.array([[-0.38], [0.1], [1.32]], dtype=float)
R_src = rodrigues_to_matrix(np.array([-0.1, 0.9, -1.2], dtype=float))
t_src = np.array([[-1.0], [-6.0], [28.0]], dtype=float)
R_dst = rodrigues_to_matrix(np.array([-0.6, 0.5, -0.9], dtype=float))
t_dst = np.array([[0.0], [0.0], [9.0]], dtype=float)

# RUN
result = transform_point_between_camera_frames_template(
    point_in_src_cam=point_in_src_cam,
    R_src=R_src,
    t_src=t_src,
    R_dst=R_dst,
    t_dst=t_dst,
    verbose=True,
)

print('ANSWER (point in destination camera):', result['answer'].reshape(-1))
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## TEMPLATE: ransac_iterations_template
#
# **When to use:** Compute minimum RANSAC iterations for target success probability.
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE
s = 465
m = 1177
p = 0.90
n = 4

# RUN
result = ransac_iterations_template(s=s, m=m, p=p, n=n, verbose=True)

print('ANSWER (minimum iterations):', result['answer'])
print('RAW N:', result['intermediates']['raw_N'])
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## TEMPLATE: ransac_threshold_from_sigma_template
#
# **When to use:** Convert Gaussian noise sigma to RANSAC inlier threshold using chi-square quantile.
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE
sigma = 1.4
confidence = 0.95
dof = 1      # use 1 or 2 depending on residual definition
squared = True

# RUN
result = ransac_threshold_from_sigma_template(
    sigma=sigma,
    confidence=confidence,
    dof=dof,
    squared=squared,
    verbose=True,
)

print('ANSWER (threshold):', result['answer'])
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## TEMPLATE: structured_light_phase_unwrap_pixel_template
#
# **When to use:** Estimate unwrapped phase from primary/secondary structured-light intensity sequences.
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE
n1 = 40
n2 = 41
primary = np.array([12, 9, 10, 13, 18, 25, 33, 40, 46, 49, 48, 45, 39, 31, 23, 17], dtype=float)
secondary = np.array([15, 29, 43, 49, 43, 29, 15, 10], dtype=float)

# RUN
result = structured_light_phase_unwrap_pixel_template(
    primary=primary,
    secondary=secondary,
    n1=n1,
    n2=n2,
    verbose=True,
)

print('ANSWER (theta_est):', result['answer'])
print('theta_primary:', result['intermediates']['theta_primary'])
print('theta_secondary:', result['intermediates']['theta_secondary'])
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## TEMPLATE: line_ransac_inlier_count_template
#
# **When to use:** Count inliers to a line hypothesis from 2 points under distance threshold tau.
#
# **PASTE INPUTS HERE:** Edit values in the next code cell.
#
# **RUN:** Execute the next code cell.
#
# **Output answer:** `result["answer"]`
#
# **Common traps:** `result["common_traps"]`

# %%
# PASTE INPUTS HERE (Option A: use npy file)
npy_path = Path('notebooks/media/ransac.npy')
tau = 0.2

# Option B: pass direct values
# points = ...  # shape 2xN
# x1 = ...      # shape (2,) or (2,1)
# x2 = ...

# RUN
result = line_ransac_inlier_count_template(
    npy_path=npy_path,
    # points=points, x1=x1, x2=x2,
    tau=tau,
    verbose=True,
)

print('ANSWER (inlier count):', result['answer'])
print('LINE [a,b,c]:', result['intermediates']['line'].reshape(-1))
print('COMMON TRAPS:')
for trap in result['common_traps']:
    print('-', trap)

# %% [markdown]
# ## Example Calls (2023/2024 Values)
#
# These call the separated example wrappers in `exam_templates/priority_a_templates.py`.
# Use them to sanity-check your environment before the exam or between questions.

# %%
example_2024_q1_project_3d_point(verbose=True)
example_2024_q2_estimate_homography(verbose=True)
example_2024_q4_distortion(verbose=True)
example_2024_q6_harris(verbose=True)
example_2024_q9_rootsift_ratio(verbose=True)
example_2024_q10_zhang_focal(verbose=True)
example_2024_q15_epipolar_distance(verbose=True)
example_2024_q16_triangulate_nonlin(verbose=True)
example_2024_q17_camera_center(verbose=True)
example_2024_q18_transform_point(verbose=True)
example_2024_q19_ransac_iterations(verbose=True)
example_2024_q20_ransac_threshold_dof1(verbose=True)
example_2024_q20_ransac_threshold_dof2(verbose=True)
example_2024_q21_structured_light(verbose=True)
example_2023_q13_line_inlier_count(verbose=True)
example_2023_q14_ransac_iterations(verbose=True)
